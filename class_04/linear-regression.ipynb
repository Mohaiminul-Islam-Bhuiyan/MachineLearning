# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Height-Weight Data.csv")

# %%
df
# Out:
#          Height      Weight
# 0     73.847017  241.893563
# 1     68.781904  162.310473
# 2     74.110105  212.740856
# 3     71.730978  220.042470
# 4     69.881796  206.349801
# ...         ...         ...
# 3496  69.296830  185.649086
# 3497  70.542201  210.198845
# 3498  73.912549  202.429960
# 3499  67.396021  144.277671
# 3500  72.738970  187.222909
#
# [3501 rows x 2 columns]

# %%
df.Height.describe()
# Out:
# count    3501.000000
# mean       69.024411
# std         2.858583
# min        59.380650
# 25%        67.193523
# 50%        69.044211
# 75%        70.976491
# max        78.998742
# Name: Height, dtype: float64

# %%
plt.boxplot(df['Height'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27396fc2ac0>,
#   <matplotlib.lines.Line2D at 0x27396fc2d90>],
#  'caps': [<matplotlib.lines.Line2D at 0x27396fd40a0>,
#   <matplotlib.lines.Line2D at 0x27396fd4370>],
#  'boxes': [<matplotlib.lines.Line2D at 0x27396fc27f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x27396fd4640>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27396fd4910>],
#  'means': []}

# %%
df.shape
# Out:
# (3501, 2)

# %%
df.shape
# Out:
# (3501, 2)

# %%
df.isnull()
# Out:
#       Height  Weight
# 0      False   False
# 1      False   False
# 2      False   False
# 3      False   False
# 4      False   False
# ...      ...     ...
# 3496   False   False
# 3497   False   False
# 3498   False   False
# 3499   False   False
# 3500   False   False
#
# [3501 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# Height    0
# Weight    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3501 entries, 0 to 3500
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Height  3501 non-null   float64
#  1   Weight  3501 non-null   float64
# dtypes: float64(2)
# memory usage: 54.8 KB

# %%
plot.scatter(df.Height, df.Weight, color="black")

# %%
plot.scatter(df.Height, df.Weight)

# %%
plot.scatter(df.Height, df.Weight)
plot.xlabel("Height in kg")
plot.ylabel("weight in inch")
plot.title("Height vs Weight")
plot.savefig("height-weight-chart-1.jpg")

# %%
df.Height.mean()
# Out:
# 69.02441087268797

# %%
df.Weight.mean()
# Out:
# 186.89125797946284

# %%
x = df[["Height"]] # x = df.drop("Weight", axis=1)

# %%
x
# Out:
#          Height
# 0     73.847017
# 1     68.781904
# 2     74.110105
# 3     71.730978
# 4     69.881796
# ...         ...
# 3496  69.296830
# 3497  70.542201
# 3498  73.912549
# 3499  67.396021
# 3500  72.738970
#
# [3501 rows x 1 columns]

# %%
y = df[["Weight"]] # y = df.drop("Height", axis = 1)

# %%
y
# Out:
#           Weight
# 0     241.893563
# 1     162.310473
# 2     212.740856
# 3     220.042470
# 4     206.349801
# ...          ...
# 3496  185.649086
# 3497  210.198845
# 3498  202.429960
# 3499  144.277671
# 3500  187.222909
#
# [3501 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression as lg

# %%
my_model = lg() # creating object for linear regression

# %%
my_model.fit(x, y) #training
# Out:
# LinearRegression()

# %%
my_model.coef_ # which is m
# Out:
# array([[5.95843786]])

# %%
my_model.intercept_ # which is c
# Out:
# array([-224.38640537])

# %%
my_model.predict([[74]])
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[216.53799664]])

# %%
my_model.predict(x)
# Out:
# array([[215.62645706],
#        [185.44629614],
#        [217.19405276],
#        ...,
#        [216.01692618],
#        [177.18859679],
#        [209.02422774]])

# %%
df["predictedWeight"] = my_model.predict(x)

# %%
df
# Out:
#          Height      Weight  predictedWeight
# 0     73.847017  241.893563       215.626457
# 1     68.781904  162.310473       185.446296
# 2     74.110105  212.740856       217.194053
# 3     71.730978  220.042470       203.018172
# 4     69.881796  206.349801       191.999933
# ...         ...         ...              ...
# 3496  69.296830  185.649086       188.514450
# 3497  70.542201  210.198845       195.934919
# 3498  73.912549  202.429960       216.016926
# 3499  67.396021  144.277671       177.188597
# 3500  72.738970  187.222909       209.024228
#
# [3501 rows x 3 columns]

# %%
plot.scatter(df.Height, df.Weight)

# %%
plot.scatter(df.Height, df.predictedWeight)

# %%
plot.plot(df.Height, df.predictedWeight)

# %%
plot.plot(df.Height.squeeze(), df.predictedWeight) # x axis showing height and y axis showing predicted weight
plot.scatter(df.Height, df.Weight, color="black")
plot.xlabel("Height in inch")
plot.ylabel("Predicted-Weight in kg")
plot.title("height vs predicted weight")
plot.savefig("height-vs-predicted-weight.png")

# %%
my_model.score(x,y)
# Out:
# 0.7323584758139253

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
mean_squared_error(df.Weight, df.predictedWeight)
# Out:
# 105.99179779708444

# %%
mean_absolute_error(df.Weight, df.predictedWeight)
# Out:
# 8.070234283451889
